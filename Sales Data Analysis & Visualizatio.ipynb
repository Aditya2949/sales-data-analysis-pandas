# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# now read our data file
df = pd.read_csv('product_sales_dataset.csv')

# %%
# now we inspect the data
df.head(10)
# Out:
#    Order_ID Order_Date       Customer_Name            City          State  \
# 0         1   08-23-23        Bianca Brown         Jackson    Mississippi
# 1         2   12-20-24       Jared Edwards    Grand Rapids       Michigan
# 2         3   01-29-24        Susan Valdez     Minneapolis      Minnesota
# 3         4   11-29-24       Tina Williams     Tallahassee        Florida
# 4         5   09-21-23    Catherine Gordon       Baltimore       Maryland
# 5         6   10-18-24    Brittany Johnson          Boston  Massachusetts
# 6         7   12-11-24  Katie Rodriguez MD         Seattle     Washington
# 7         8   05-05-23          John Davis           Tulsa       Oklahoma
# 8         9   10-25-23        Edward Hicks  Salt Lake City           Utah
# 9        10   10-15-23   Carrie Cunningham      Fort Smith       Arkansas
#
#    Region        Country            Category       Sub_Category  \
# 0   South  United States         Accessories  Small Electronics
# 1  Centre  United States         Accessories  Small Electronics
# 2  Centre  United States  Clothing & Apparel         Sportswear
# 3   South  United States  Clothing & Apparel         Sportswear
# 4    East  United States         Accessories               Bags
# 5    East  United States         Electronics    Home Appliances
# 6    West  United States         Electronics          Wearables
# 7   South  United States  Clothing & Apparel         Men's Wear
# 8    West  United States  Clothing & Apparel           Footwear
# 9   South  United States         Electronics        Smartphones
#
#        Product_Name  Quantity   Unit_Price    Revenue    Profit
# 0        Phone Case         3        201.01     603.03    221.49
# 1    Charging Cable         4         74.30     297.20     97.09
# 2  Nike Air Force 1         1         68.19      68.19     25.47
# 3  Adidas Tracksuit         3        209.64     628.92    231.38
# 4          Backpack         1        216.63     216.63     42.46
# 5       Instant Pot         1        701.15     701.15     90.63
# 6       Apple Watch         2        875.34    1750.68    320.37
# 7      Levi's Jeans         1        329.29     329.29     65.91
# 8  Timberland Boots         2        115.35     230.70     87.44
# 9   Apple iPhone 14         5        509.51    2547.55    472.90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Order_ID       200000 non-null  int64
#  1   Order_Date     200000 non-null  object
#  2   Customer_Name  200000 non-null  object
#  3   City           200000 non-null  object
#  4   State          200000 non-null  object
#  5   Region         200000 non-null  object
#  6   Country        200000 non-null  object
#  7   Category       200000 non-null  object
#  8   Sub_Category   200000 non-null  object
#  9   Product_Name   200000 non-null  object
#  10  Quantity       200000 non-null  int64
#  11   Unit_Price    200000 non-null  float64
#  12   Revenue       200000 non-null  float64
#  13   Profit        200000 non-null  float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 21.4+ MB

# %%
# now we saw our data dimentions (rows and columns)
df.shape
# Out:
# (200000, 14)

# %%
# checking null values count in columns
df.isnull().sum()
# Out:
# Order_ID         0
# Order_Date       0
# Customer_Name    0
# City             0
# State            0
# Region           0
# Country          0
# Category         0
# Sub_Category     0
# Product_Name     0
# Quantity         0
#  Unit_Price      0
#  Revenue         0
#  Profit          0
# dtype: int64

# %%
# it checks tha data types of our columns
df.dtypes
# Out:
# Order_ID           int64
# Order_Date        object
# Customer_Name     object
# City              object
# State             object
# Region            object
# Country           object
# Category          object
# Sub_Category      object
# Product_Name      object
# Quantity           int64
#  Unit_Price      float64
#  Revenue         float64
#  Profit          float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Name', 'City', 'State', 'Region',
#        'Country', 'Category', 'Sub_Category', 'Product_Name', 'Quantity',
#        ' Unit_Price ', ' Revenue ', ' Profit '],
#       dtype='object')

# %%
# it converts it into Datetime
df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
# check is it convert or not
df.dtypes
# Out:
# Order_ID                  int64
# Order_Date       datetime64[ns]
# Customer_Name            object
# City                     object
# State                    object
# Region                   object
# Country                  object
# Category                 object
# Sub_Category             object
# Product_Name             object
# Quantity                  int64
#  Unit_Price             float64
#  Revenue                float64
#  Profit                 float64
# dtype: object

# %%
# now check duplicate values
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 199995    False
# 199996    False
# 199997    False
# 199998    False
# 199999    False
# Length: 200000, dtype: bool

# %%
# now remove duplicates
df.drop_duplicates(inplace=True)

# %%
# create new columns
df['Month']=df['Order_Date'].dt.month

# %%
df['Year']=df['Order_Date'].dt.year

# %%
# remove spaces betwwen columns
df.columns=df.columns.str.strip()

# %%
# now perform some operations and get some information
df['Profit'].sum()
# Out:
# np.float64(31548608.13)

# %%
df
# Out:
#         Order_ID Order_Date     Customer_Name           City          State  \
# 0              1 2023-08-23      Bianca Brown        Jackson    Mississippi
# 1              2 2024-12-20     Jared Edwards   Grand Rapids       Michigan
# 2              3 2024-01-29      Susan Valdez    Minneapolis      Minnesota
# 3              4 2024-11-29     Tina Williams    Tallahassee        Florida
# 4              5 2023-09-21  Catherine Gordon      Baltimore       Maryland
# ...          ...        ...               ...            ...            ...
# 199995    199996 2023-08-15   William Jackson         Boston  Massachusetts
# 199996    199997 2023-10-17    Sharon Ferrell       Bismarck   North Dakota
# 199997    199998 2023-12-03      Katie Rivera       Santa Fe     New Mexico
# 199998    199999 2023-12-08     Lisa Sullivan  New York City       New York
# 199999    200000 2024-12-13   Jessica Mueller        Augusta          Maine
#
#         Region        Country            Category          Sub_Category  \
# 0        South  United States         Accessories     Small Electronics
# 1       Centre  United States         Accessories     Small Electronics
# 2       Centre  United States  Clothing & Apparel            Sportswear
# 3        South  United States  Clothing & Apparel            Sportswear
# 4         East  United States         Accessories                  Bags
# ...        ...            ...                 ...                   ...
# 199995    East  United States    Home & Furniture               Storage
# 199996  Centre  United States         Accessories     Small Electronics
# 199997    West  United States         Accessories  Wearable Accessories
# 199998    East  United States  Clothing & Apparel          Women's Wear
# 199999    East  United States  Clothing & Apparel            Men's Wear
#
#             Product_Name  Quantity  Unit_Price  Revenue  Profit  Month  Year
# 0             Phone Case         3      201.01   603.03  221.49      8  2023
# 1         Charging Cable         4       74.30   297.20   97.09     12  2024
# 2       Nike Air Force 1         1       68.19    68.19   25.47      1  2024
# 3       Adidas Tracksuit         3      209.64   628.92  231.38     11  2024
# 4               Backpack         1      216.63   216.63   42.46      9  2023
# ...                  ...       ...         ...      ...     ...    ...   ...
# 199995      Storage Rack         4      254.42  1017.68  334.72      8  2023
# 199996    Charging Cable         1      237.04   237.04   46.53     10  2023
# 199997        Sunglasses         2      106.83   213.66  102.57     12  2023
# 199998       Zara Blouse         2      353.01   706.02  288.74     12  2023
# 199999        GAP Hoodie         1      216.68   216.68   59.10     12  2024
#
# [200000 rows x 16 columns]

# %%
# monthly sales products and their quantity
monthly = df.groupby('Month')['Quantity'].sum()

# %%
monthly
# Out:
# Month
# 1     22724
# 2     14769
# 3     20829
# 4     22318
# 5     25193
# 6     24605
# 7     23198
# 8     22874
# 9     24529
# 10    45585
# 11    71026
# 12    53150
# Name: Quantity, dtype: int64

# %%
# now visulize it in plot
plt.figure(figsize=(10,5))
monthly.plot()
plt.title('Sales in monthly basis')
plt.xlabel('Month')
plt.ylabel('Quantity')
plt.show()

# %%
# now calculate and analyse profit by category
category_sales=df.groupby('Category')['Profit'].sum()

# %%
category_sales
# Out:
# Category
# Accessories            3438046.28
# Clothing & Apparel     8826851.49
# Electronics            8065113.92
# Home & Furniture      11218596.44
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=category_sales.index,y=category_sales.values,hue=category_sales)
plt.title('Profit by category')
plt.show()

# %%
# now calculate profit on perticular product
top_products = df.groupby('Product_Name')['Profit'].sum()

# %%
top_products
# Out:
# Product_Name
# Adidas Tracksuit          766612.16
# Apple Watch               957992.87
# Apple iPhone 14           808671.16
# Ashley Recliner           469158.18
# Backpack                  482029.14
# Belt                      260711.04
# Bose Soundbar             321231.11
# Brooklinen Sheets         933904.24
# Carter's Onesie           907369.41
# Charging Cable            385761.32
# Children's Hoodie         700414.08
# Closet Organizer          771464.27
# Cookware Set              461471.10
# Crocs                     570562.06
# Dell XPS 13               438733.96
# Dining Table Set          388640.92
# Dyson Vacuum              262741.41
# Fitbit Charge             335264.03
# GAP Hoodie                492979.33
# Google Pixel 7            184425.54
# IKEA Sofa                 824017.25
# Instant Pot              1689924.16
# KitchenAid Mixer          944239.08
# LG OLED TV                373555.37
# Lenovo ThinkPad           258881.28
# Levi's Jeans              720231.96
# MacBook Air              1028767.59
# Nike Air Force 1         1128698.91
# Nike Running Shoes        839269.74
# Office Chair              599331.99
# Old Navy Dress            960337.85
# Phone Case                544161.64
# Power Bank                340063.47
# Samsung Galaxy S23        542627.11
# Samsung Galaxy Tab        393909.34
# Sony Bravia TV            431253.00
# Storage Rack             1052179.55
# Sunglasses                495249.75
# Tempur-Pedic Mattress    2134208.80
# Throw Pillows             820062.65
# Timberland Boots          352921.84
# Tote Bag                  225893.79
# Under Armour T-Shirt      615336.08
# Vase                      467435.72
# Wall Art                  608015.90
# Wallet                    379210.90
# Watch Strap               324965.23
# Zara Blouse               772118.07
# iPad Pro                  781602.78
# Name: Profit, dtype: float64

# %%
# getting top 10 products
# sort by decending order
top_products = df.groupby('Product_Name')['Profit'].sum().sort_values(ascending=False).head(10)

# %%
top_products
# Out:
# Product_Name
# Tempur-Pedic Mattress    2134208.80
# Instant Pot              1689924.16
# Nike Air Force 1         1128698.91
# Storage Rack             1052179.55
# MacBook Air              1028767.59
# Old Navy Dress            960337.85
# Apple Watch               957992.87
# KitchenAid Mixer          944239.08
# Brooklinen Sheets         933904.24
# Carter's Onesie           907369.41
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=top_products.values,y=top_products.index,hue=top_products)
plt.title('Profit on perticular product')
plt.show()

# %%
# now we calculate te Region wise Revenue
region_revenue=df.groupby('Region')['Revenue'].sum()

# %%
region_revenue
# Out:
# Region
# Centre    36081894.34
# East      44980048.22
# South     25102960.64
# West      36242841.73
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(7,7))
plt.pie(region_revenue,labels=region_revenue.index,autopct='%0.1f%%')
plt.title('Region wise Revenue')
plt.show()

# %% [markdown]
# # **East region is the top-performing revenue region**
